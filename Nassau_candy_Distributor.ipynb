# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\I SKY\Downloads/Nassau Candy Distributor.csv")
df.head()
# Out:
#    Row ID                      Order ID  Order Date   Ship Date  \
# 0       1  US-2021-103800-CHO-MIL-31000  03-01-2024  30-06-2026
# 1       2  US-2021-112326-CHO-TRI-54000  04-01-2024  01-07-2026
# 2       3  US-2021-112326-CHO-NUT-13000  04-01-2024  01-07-2026
# 3       4  US-2021-112326-CHO-SCR-58000  04-01-2024  01-07-2026
# 4       5  US-2021-141817-CHO-TRI-54000  05-01-2024  05-07-2026
#
#         Ship Mode  Customer ID Country/Region          City State/Province  \
# 0  Standard Class       103800  United States       Houston          Texas
# 1  Standard Class       112326  United States    Naperville       Illinois
# 2  Standard Class       112326  United States    Naperville       Illinois
# 3  Standard Class       112326  United States    Naperville       Illinois
# 4  Standard Class       141817  United States  Philadelphia   Pennsylvania
#
#   Postal Code   Division    Region     Product ID  \
# 0       77095  Chocolate  Interior  CHO-MIL-31000
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Country/Region', 'City', 'State/Province',
#        'Postal Code', 'Division', 'Region', 'Product ID', 'Product Name',
#        'Sales', 'Units', 'Gross Profit', 'Cost'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          10194 non-null  int64
#  1   Order ID        10194 non-null  object
#  2   Order Date      10194 non-null  object
#  3   Ship Date       10194 non-null  object
#  4   Ship Mode       10194 non-null  object
#  5   Customer ID     10194 non-null  int64
#  6   Country/Region  10194 non-null  object
#  7   City            10194 non-null  object
#  8   State/Province  10194 non-null  object
#  9   Postal Code     10194 non-null  object
#  10  Division        10194 non-null  object
#  11  Region          10194 non-null  object
#  12  Product ID      10194 non-null  object
#  13  Product Name    10194 non-null  object
#  14  Sales           10194 non-null  float64
#  15  Units           10194 non-null  int64
#  16  Gross Profit    10194 non-null  float64
# ...

# %%
df.isnull().sum()  # No Missing values ..
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Country/Region    0
# City              0
# State/Province    0
# Postal Code       0
# Division          0
# Region            0
# Product ID        0
# Product Name      0
# Sales             0
# Units             0
# Gross Profit      0
# Cost              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# This one line replaces almost all of your previous code!
df['Order Date'] = pd.to_datetime(df['Order Date'], format='mixed', dayfirst=True)

# You can do the same for Ship Date
df['Ship Date'] = pd.to_datetime(df['Ship Date'], format='mixed', dayfirst=True)

# %%
df.head()
# Out:
#    Row ID                      Order ID Order Date  Ship Date       Ship Mode  \
# 0       1  US-2021-103800-CHO-MIL-31000 2024-01-03 2026-06-30  Standard Class
# 1       2  US-2021-112326-CHO-TRI-54000 2024-01-04 2026-07-01  Standard Class
# 2       3  US-2021-112326-CHO-NUT-13000 2024-01-04 2026-07-01  Standard Class
# 3       4  US-2021-112326-CHO-SCR-58000 2024-01-04 2026-07-01  Standard Class
# 4       5  US-2021-141817-CHO-TRI-54000 2024-01-05 2026-07-05  Standard Class
#
#    Customer ID Country/Region          City State/Province Postal Code  \
# 0       103800  United States       Houston          Texas       77095
# 1       112326  United States    Naperville       Illinois       60540
# 2       112326  United States    Naperville       Illinois       60540
# 3       112326  United States    Naperville       Illinois       60540
# 4       141817  United States  Philadelphia   Pennsylvania       19143
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          10194 non-null  int64
#  1   Order ID        10194 non-null  object
#  2   Order Date      10194 non-null  datetime64[ns]
#  3   Ship Date       10194 non-null  datetime64[ns]
#  4   Ship Mode       10194 non-null  object
#  5   Customer ID     10194 non-null  int64
#  6   Country/Region  10194 non-null  object
#  7   City            10194 non-null  object
#  8   State/Province  10194 non-null  object
#  9   Postal Code     10194 non-null  object
#  10  Division        10194 non-null  object
#  11  Region          10194 non-null  object
#  12  Product ID      10194 non-null  object
#  13  Product Name    10194 non-null  object
#  14  Sales           10194 non-null  float64
#  15  Units           10194 non-null  int64
# ...

# %%
print(f"Original DataFrame shape: {df.shape}")

# Calculate lead time (difference between Ship Date and Order Date)
df['Lead Time'] = df['Ship Date'] - df['Order Date']

# Filter out rows with negative lead times
df = df[df['Lead Time'] >= pd.Timedelta(0)]

print(f"DataFrame shape after removing negative lead times: {df.shape}")

display(df.head())
# Out:
# Original DataFrame shape: (10194, 18)
# DataFrame shape after removing negative lead times: (10194, 19)
#    Row ID                      Order ID Order Date  Ship Date       Ship Mode  \
# 0       1  US-2021-103800-CHO-MIL-31000 2024-01-03 2026-06-30  Standard Class
# 1       2  US-2021-112326-CHO-TRI-54000 2024-01-04 2026-07-01  Standard Class
# 2       3  US-2021-112326-CHO-NUT-13000 2024-01-04 2026-07-01  Standard Class
# 3       4  US-2021-112326-CHO-SCR-58000 2024-01-04 2026-07-01  Standard Class
# 4       5  US-2021-141817-CHO-TRI-54000 2024-01-05 2026-07-05  Standard Class
#
#    Customer ID Country/Region          City State/Province Postal Code  \
# 0       103800  United States       Houston          Texas       77095
# 1       112326  United States    Naperville       Illinois       60540
# 2       112326  United States    Naperville       Illinois       60540
# 3       112326  United States    Naperville       Illinois       60540
# ...

# %%
factory_data = {
    'Factory': ['Lot\'s O\' Nuts', 'Wicked Choccy\'s', 'Sugar Shack', 'Secret Factory', 'The Other Factory'],
    'Latitude': [32.881893, 32.076176, 48.11914, 41.446333, 35.1175],
    'Longitude': [-111.768036, -81.088371, -96.18115, -90.565487, -89.971107]
}
factory_df = pd.DataFrame(factory_data)

display(factory_df.head())
# Out:
#              Factory   Latitude   Longitude
# 0      Lot's O' Nuts  32.881893 -111.768036
# 1    Wicked Choccy's  32.076176  -81.088371
# 2        Sugar Shack  48.119140  -96.181150
# 3     Secret Factory  41.446333  -90.565487
# 4  The Other Factory  35.117500  -89.971107

# %%
product_factory_data = {
    'Division': ['Chocolate', 'Chocolate', 'Chocolate', 'Chocolate', 'Chocolate', 'Sugar', 'Sugar', 'Sugar', 'Sugar', 'Other', 'Sugar', 'Sugar', 'Other', 'Other', 'Other'],
    'Product Name': ['Wonka Bar - Nutty Crunch Surprise', 'Wonka Bar - Fudge Mallows', 'Wonka Bar -Scrumdiddlyumptious', 'Wonka Bar - Milk Chocolate', 'Wonka Bar - Triple Dazzle Caramel', 'Laffy Taffy', 'SweeTARTS', 'Nerds', 'Fun Dip', 'Fizzy Lifting Drinks', 'Everlasting Gobstopper', 'Hair Toffee', 'Lickable Wallpaper', 'Wonka Gum', 'Kazookles'],
    'Factory': ['Lot\'s O\' Nuts', 'Lot\'s O\' Nuts', 'Lot\'s O\' Nuts', 'Wicked Choccy\'s', 'Wicked Choccy\'s', 'Sugar Shack', 'Sugar Shack', 'Sugar Shack', 'Sugar Shack', 'Sugar Shack', 'Secret Factory', 'The Other Factory', 'Secret Factory', 'Secret Factory', 'The Other Factory']
}
product_factory_df = pd.DataFrame(product_factory_data)
display(product_factory_df.head())
# Out:
#     Division                       Product Name          Factory
# 0  Chocolate  Wonka Bar - Nutty Crunch Surprise    Lot's O' Nuts
# 1  Chocolate          Wonka Bar - Fudge Mallows    Lot's O' Nuts
# 2  Chocolate     Wonka Bar -Scrumdiddlyumptious    Lot's O' Nuts
# 3  Chocolate         Wonka Bar - Milk Chocolate  Wicked Choccy's
# 4  Chocolate  Wonka Bar - Triple Dazzle Caramel  Wicked Choccy's

# %%
# Merge df with product_factory_df on 'Product Name'
df_merged = pd.merge(df, product_factory_df, on='Product Name', how='left')

# Merge the result with factory_df on 'Factory'
df_merged = pd.merge(df_merged, factory_df, on='Factory', how='left')

display(df_merged.head())
df_merged.shape
# Out:
#    Row ID                      Order ID Order Date  Ship Date       Ship Mode  \
# 0       1  US-2021-103800-CHO-MIL-31000 2024-01-03 2026-06-30  Standard Class
# 1       2  US-2021-112326-CHO-TRI-54000 2024-01-04 2026-07-01  Standard Class
# 2       3  US-2021-112326-CHO-NUT-13000 2024-01-04 2026-07-01  Standard Class
# 3       4  US-2021-112326-CHO-SCR-58000 2024-01-04 2026-07-01  Standard Class
# 4       5  US-2021-141817-CHO-TRI-54000 2024-01-05 2026-07-05  Standard Class
#
#    Customer ID Country/Region          City State/Province Postal Code  ...  \
# 0       103800  United States       Houston          Texas       77095  ...
# 1       112326  United States    Naperville       Illinois       60540  ...
# 2       112326  United States    Naperville       Illinois       60540  ...
# 3       112326  United States    Naperville       Illinois       60540  ...
# 4       141817  United States  Philadelphia   Pennsylvania       19143  ...
#
# ...

# %% [markdown]
# Categorizing Routes by Factory to Customer Region

# %%
factory_region_routes = df_merged.groupby(['Factory', 'Region'])['Order ID'].nunique().reset_index()
factory_region_routes.rename(columns={'Order ID': 'Number of Orders'}, inplace=True)
display(factory_region_routes.head())
# Out:
#           Factory    Region  Number of Orders
# 0   Lot's O' Nuts  Atlantic              1378
# 1   Lot's O' Nuts      Gulf               745
# 2   Lot's O' Nuts  Interior              1113
# 3   Lot's O' Nuts   Pacific              1524
# 4  Secret Factory  Atlantic                70

# %% [markdown]
#  Categorizing Routes by Factory to Customer State

# %%
factory_state_routes = df_merged.groupby(['Factory', 'State/Province'])['Order ID'].nunique().reset_index()
factory_state_routes.rename(columns={'Order ID': 'Number of Orders'}, inplace=True)
display(factory_state_routes.head())
# Out:
#          Factory    State/Province  Number of Orders
# 0  Lot's O' Nuts           Alabama                30
# 1  Lot's O' Nuts           Alberta                12
# 2  Lot's O' Nuts           Arizona                94
# 3  Lot's O' Nuts          Arkansas                25
# 4  Lot's O' Nuts  British Columbia                18

# %% [markdown]
# Shipments by Ship Mode

# %%
shipments_by_mode = df_merged.groupby('Ship Mode')['Order ID'].nunique().reset_index()
shipments_by_mode.rename(columns={'Order ID': 'Number of Orders'}, inplace=True)
display(shipments_by_mode)
# Out:
#         Ship Mode  Number of Orders
# 0     First Class              1312
# 1        Same Day               442
# 2    Second Class              1653
# 3  Standard Class              5142

# %% [markdown]
#  Route Analysis: Factory to Customer Region

# %%
route_region_analysis = df_merged.groupby(['Factory', 'Region']).agg(
    Total_Shipments=('Order ID', 'nunique'),
    Average_Shipping_Lead_Time=('Lead Time', 'mean'),
    Lead_Time_Variability=('Lead Time', 'std')
).reset_index()
display(route_region_analysis.head())
# Out:
#           Factory    Region  Total_Shipments   Average_Shipping_Lead_Time  \
# 0   Lot's O' Nuts  Atlantic             1378 1326 days 19:48:35.111378688
# 1   Lot's O' Nuts      Gulf              745 1313 days 23:24:40.936454848
# 2   Lot's O' Nuts  Interior             1113 1324 days 04:42:19.894019680
# 3   Lot's O' Nuts   Pacific             1524 1317 days 12:40:06.618863760
# 4  Secret Factory  Atlantic               70           1349 days 06:00:00
#
#         Lead_Time_Variability
# 0 255 days 23:45:39.903954604
# 1 266 days 14:06:34.977844756
# 2 258 days 09:52:28.258112712
# 3 266 days 16:08:41.264866764
# 4 280 days 17:13:10.154942672

# %% [markdown]
# Route Analysis: Factory to Customer State/Province

# %%
route_state_analysis = df_merged.groupby(['Factory', 'State/Province']).agg(
    Total_Shipments=('Order ID', 'nunique'),
    Average_Shipping_Lead_Time=('Lead Time', 'mean'),
    Lead_Time_Variability=('Lead Time', 'std')
).reset_index()
display(route_state_analysis.head())
# Out:
#          Factory    State/Province  Total_Shipments  \
# 0  Lot's O' Nuts           Alabama               30
# 1  Lot's O' Nuts           Alberta               12
# 2  Lot's O' Nuts           Arizona               94
# 3  Lot's O' Nuts          Arkansas               25
# 4  Lot's O' Nuts  British Columbia               18
#
#     Average_Shipping_Lead_Time       Lead_Time_Variability
# 0 1295 days 04:56:28.235294112 253 days 01:41:16.642641672
# 1           1273 days 21:00:00 266 days 22:11:10.536614560
# 2 1306 days 04:45:24.324324320 253 days 21:37:39.828353616
# 3 1285 days 08:30:58.064516128 274 days 12:41:55.784071776
# 4           1273 days 18:40:00 307 days 01:59:11.670480360

# %% [markdown]
# ### Route Ranking by Average Lead Time (Factory to Region)

# %%
# Sort routes by Average_Shipping_Lead_Time from fastest to slowest
ranked_region_routes = route_region_analysis.sort_values(by='Average_Shipping_Lead_Time', ascending=True)
display(ranked_region_routes.head())
# Out:
#               Factory    Region  Total_Shipments   Average_Shipping_Lead_Time  \
# 9         Sugar Shack      Gulf                4           1091 days 06:00:00
# 14  The Other Factory  Interior               11 1206 days 15:16:21.818181824
# 13  The Other Factory      Gulf               19 1272 days 15:09:28.421052624
# 12  The Other Factory  Atlantic               37 1282 days 17:41:03.157894736
# 6      Secret Factory  Interior               45           1289 days 02:08:00
#
#          Lead_Time_Variability
# 9  210 days 10:44:44.475071328
# 14 274 days 10:16:39.249020180
# 13 272 days 17:34:31.483063944
# 12 262 days 04:05:42.951901732
# 6  311 days 05:24:49.266562620

# %% [markdown]
# ### Top 10 Most Efficient Routes (Factory to Region)

# %%
top_10_efficient_regions = ranked_region_routes.head(10)
display(top_10_efficient_regions)
# Out:
#               Factory    Region  Total_Shipments   Average_Shipping_Lead_Time  \
# 9         Sugar Shack      Gulf                4           1091 days 06:00:00
# 14  The Other Factory  Interior               11 1206 days 15:16:21.818181824
# 13  The Other Factory      Gulf               19 1272 days 15:09:28.421052624
# 12  The Other Factory  Atlantic               37 1282 days 17:41:03.157894736
# 6      Secret Factory  Interior               45           1289 days 02:08:00
# 15  The Other Factory   Pacific               31           1307 days 05:15:00
# 7      Secret Factory   Pacific               63 1307 days 17:31:25.714285712
# 17    Wicked Choccy's      Gulf              547 1309 days 02:42:53.755656112
# 1       Lot's O' Nuts      Gulf              745 1313 days 23:24:40.936454848
# 16    Wicked Choccy's  Atlantic              973 1315 days 23:13:04.962406016
#
#          Lead_Time_Variability
# 9  210 days 10:44:44.475071328
# 14 274 days 10:16:39.249020180
# ...

# %% [markdown]
# ### Bottom 10 Least Efficient Routes (Factory to Region)

# %%
bottom_10_inefficient_regions = ranked_region_routes.tail(10)
display(bottom_10_inefficient_regions)
# Out:
#             Factory    Region  Total_Shipments   Average_Shipping_Lead_Time  \
# 3     Lot's O' Nuts   Pacific             1524 1317 days 12:40:06.618863760
# 10      Sugar Shack  Interior                8           1318 days 15:00:00
# 2     Lot's O' Nuts  Interior             1113 1324 days 04:42:19.894019680
# 18  Wicked Choccy's  Interior              802 1324 days 13:14:16.421052624
# 0     Lot's O' Nuts  Atlantic             1378 1326 days 19:48:35.111378688
# 19  Wicked Choccy's   Pacific             1123 1329 days 02:25:55.886736208
# 5    Secret Factory      Gulf               35 1332 days 12:58:22.702702704
# 4    Secret Factory  Atlantic               70           1349 days 06:00:00
# 8       Sugar Shack  Atlantic               18           1375 days 09:20:00
# 11      Sugar Shack   Pacific                3           1516 days 16:00:00
#
#          Lead_Time_Variability
# 3  266 days 16:08:41.264866764
# 10 235 days 06:10:27.954471604
# 2  258 days 09:52:28.258112712
# ...

# %% [markdown]
# Route Ranking by Average Lead Time (Factory to State/Province)

# %%
# Sort routes by Average_Shipping_Lead_Time from fastest to slowest
ranked_state_routes = route_state_analysis.sort_values(by='Average_Shipping_Lead_Time', ascending=True)
display(ranked_state_routes.head())
# Out:
#                Factory State/Province  Total_Shipments  \
# 76      Secret Factory       Nebraska                1
# 80      Secret Factory     New Mexico                2
# 121  The Other Factory      Louisiana                1
# 115  The Other Factory    Connecticut                2
# 158    Wicked Choccy's          Maine                2
#
#     Average_Shipping_Lead_Time     Lead_Time_Variability
# 76           906 days 00:00:00                       NaT
# 80           906 days 00:00:00 2 days 19:52:56.103578070
# 121          907 days 00:00:00                       NaT
# 115          907 days 12:00:00 2 days 02:54:42.077683553
# 158          908 days 00:00:00           0 days 00:00:00

# %% [markdown]
# Top 10 Most Efficient Routes (Factory to State/Province)

# %%
top_10_efficient_states = ranked_state_routes.head(10)
display(top_10_efficient_states)
# Out:
#                Factory  State/Province  Total_Shipments  \
# 76      Secret Factory        Nebraska                1
# 80      Secret Factory      New Mexico                2
# 121  The Other Factory       Louisiana                1
# 115  The Other Factory     Connecticut                2
# 158    Wicked Choccy's           Maine                2
# 75      Secret Factory     Mississippi                1
# 70      Secret Factory       Louisiana                2
# 64      Secret Factory        Delaware                1
# 88      Secret Factory  South Carolina                1
# 74      Secret Factory       Minnesota                1
#
#     Average_Shipping_Lead_Time     Lead_Time_Variability
# 76           906 days 00:00:00                       NaT
# 80           906 days 00:00:00 2 days 19:52:56.103578070
# 121          907 days 00:00:00                       NaT
# 115          907 days 12:00:00 2 days 02:54:42.077683553
# 158          908 days 00:00:00           0 days 00:00:00
# ...

# %% [markdown]
#  Bottom 10 Least Efficient Routes (Factory to State/Province)

# %%
bottom_10_inefficient_states = ranked_state_routes.tail(10)
display(bottom_10_inefficient_states)
# Out:
#                Factory State/Province  Total_Shipments  \
# 69      Secret Factory       Kentucky                2
# 110        Sugar Shack     Washington                1
# 125  The Other Factory         Nevada                1
# 63      Secret Factory    Connecticut                1
# 97         Sugar Shack     California                1
# 37       Lot's O' Nuts   North Dakota                4
# 194    Wicked Choccy's  West Virginia                2
# 78      Secret Factory  New Hampshire                1
# 98         Sugar Shack    Connecticut                1
# 103        Sugar Shack     New Jersey                1
#
#     Average_Shipping_Lead_Time     Lead_Time_Variability
# 69          1637 days 12:00:00 0 days 16:58:14.025894517
# 110         1638 days 00:00:00                       NaT
# 125         1638 days 00:00:00                       NaT
# 63          1638 days 00:00:00                       NaT
# 97          1638 days 00:00:00                       NaT
# ...

# %% [markdown]
# Performance Comparison Across Ship Modes

# %%
ship_mode_performance = df_merged.groupby('Ship Mode').agg(
    Total_Shipments=('Order ID', 'nunique'),
    Average_Shipping_Lead_Time=('Lead Time', 'mean'),
    Lead_Time_Variability=('Lead Time', 'std')
).reset_index()
display(ship_mode_performance.sort_values(by='Average_Shipping_Lead_Time'))
# Out:
#         Ship Mode  Total_Shipments   Average_Shipping_Lead_Time  \
# 3  Standard Class             5142 1314 days 08:01:52.941176464
# 2    Second Class             1653 1323 days 20:17:20.525517936
# 1        Same Day              442 1333 days 10:37:04.497257776
# 0     First Class             1312 1338 days 06:37:12.558139536
#
#         Lead_Time_Variability
# 3 262 days 09:36:10.041529276
# 2 261 days 19:31:32.398991320
# 1 253 days 19:31:15.513476732
# 0 265 days 15:10:16.909276700

# %% [markdown]
# #Geographic Bottleneck Analysis: High Average Lead Time

# %% [markdown]
# Regions with Highest Average Lead Time

# %%
bottom_10_inefficient_regions.tail(1)
# Out:
#         Factory   Region  Total_Shipments Average_Shipping_Lead_Time  \
# 11  Sugar Shack  Pacific                3         1516 days 16:00:00
#
#          Lead_Time_Variability
# 11 210 days 03:43:55.025906052

# %% [markdown]
#  States/Provinces with Highest Average Lead Time

# %%
bottom_10_inefficient_states.tail(1)
# Out:
#          Factory State/Province  Total_Shipments Average_Shipping_Lead_Time  \
# 103  Sugar Shack     New Jersey                1                  1642 days
#
#     Lead_Time_Variability
# 103                   NaT

# %% [markdown]
# Geographic Bottleneck Analysis: High Shipment Volume + Poor Performance (Congestion-Prone)

# %%
# Calculate mean for Total_Shipments and Average_Shipping_Lead_Time for regions
mean_shipments_region = route_region_analysis['Total_Shipments'].mean()
mean_lead_time_region = route_region_analysis['Average_Shipping_Lead_Time'].mean()

# Filter for regions with high shipment volume and high average lead time
congestion_prone_regions = route_region_analysis[
    (route_region_analysis['Total_Shipments'] > mean_shipments_region) &
    (route_region_analysis['Average_Shipping_Lead_Time'] > mean_lead_time_region)
].sort_values(by='Average_Shipping_Lead_Time', ascending=False)

print(f"Mean Total Shipments (Regions): {mean_shipments_region:.2f}")
print(f"Mean Average Shipping Lead Time (Regions): {mean_lead_time_region}")
print("\nCongestion-Prone Regions (High Volume + High Lead Time):")
display(congestion_prone_regions)
# Out:
# Mean Total Shipments (Regions): 427.45
# Mean Average Shipping Lead Time (Regions): 1310 days 13:13:34.770034272
#
# Congestion-Prone Regions (High Volume + High Lead Time):
#             Factory    Region  Total_Shipments   Average_Shipping_Lead_Time  \
# 19  Wicked Choccy's   Pacific             1123 1329 days 02:25:55.886736208
# 0     Lot's O' Nuts  Atlantic             1378 1326 days 19:48:35.111378688
# 18  Wicked Choccy's  Interior              802 1324 days 13:14:16.421052624
# 2     Lot's O' Nuts  Interior             1113 1324 days 04:42:19.894019680
# 3     Lot's O' Nuts   Pacific             1524 1317 days 12:40:06.618863760
# 16  Wicked Choccy's  Atlantic              973 1315 days 23:13:04.962406016
# 1     Lot's O' Nuts      Gulf              745 1313 days 23:24:40.936454848
#
#          Lead_Time_Variability
# 19 266 days 05:15:15.631119392
# 0  255 days 23:45:39.903954604
# 18 266 days 07:49:24.887098488
# 2  258 days 09:52:28.258112712
# ...

# %%
# Calculate mean for Total_Shipments and Average_Shipping_Lead_Time for states
mean_shipments_state = route_state_analysis['Total_Shipments'].mean()
mean_lead_time_state = route_state_analysis['Average_Shipping_Lead_Time'].mean()

# Filter for states with high shipment volume and high average lead time
congestion_prone_states = route_state_analysis[
    (route_state_analysis['Total_Shipments'] > mean_shipments_state) &
    (route_state_analysis['Average_Shipping_Lead_Time'] > mean_lead_time_state)
].sort_values(by='Average_Shipping_Lead_Time', ascending=False)

print(f"Mean Total Shipments (States): {mean_shipments_state:.2f}")
print(f"Mean Average Shipping Lead Time (States): {mean_lead_time_state}")
print("\nCongestion-Prone States (High Volume + High Lead Time):")
display(congestion_prone_states)
# Out:
# Mean Total Shipments (States): 43.62
# Mean Average Shipping Lead Time (States): 1314 days 01:04:54.635398160
#
# Congestion-Prone States (High Volume + High Lead Time):
#              Factory  State/Province  Total_Shipments  \
# 153  Wicked Choccy's         Indiana               44
# 188  Wicked Choccy's       Tennessee               56
# 48     Lot's O' Nuts       Tennessee               88
# 193  Wicked Choccy's      Washington              187
# 21     Lot's O' Nuts        Maryland               44
# 55     Lot's O' Nuts       Wisconsin               44
# 14     Lot's O' Nuts         Indiana               74
# 174  Wicked Choccy's  North Carolina               91
# 6      Lot's O' Nuts        Colorado               82
# 150  Wicked Choccy's         Georgia               55
# 53     Lot's O' Nuts      Washington              230
# 181  Wicked Choccy's    Pennsylvania              188
# 32     Lot's O' Nuts      New Jersey               53
# ...

# %% [markdown]
# ### Shipping Efficiency: Standard vs. Expedited

# %%
# Define Standard and Expedited Shipping categories
standard_shipping_modes = ['Standard Class']
expedited_shipping_modes = ['First Class', 'Same Day', 'Second Class']

# Filter for Standard Shipping performance
standard_shipping_performance = ship_mode_performance[ship_mode_performance['Ship Mode'].isin(standard_shipping_modes)]

# Filter for Expedited Shipping performance
expedited_shipping_performance = ship_mode_performance[ship_mode_performance['Ship Mode'].isin(expedited_shipping_modes)]

# Calculate aggregated performance for Expedited Shipping
# We'll take a weighted average for lead time if there were volume differences, but a simple mean for illustration
expedited_avg_lead_time = expedited_shipping_performance['Average_Shipping_Lead_Time'].mean()
expedited_avg_variability = expedited_shipping_performance['Lead_Time_Variability'].mean()
expedited_total_shipments = expedited_shipping_performance['Total_Shipments'].sum()

print("**Standard Shipping Performance:**")
display(standard_shipping_performance)

print("**Expedited Shipping Performance (Aggregated):**")
print(f"Total Shipments: {expedited_total_shipments}")
print(f"Average Shipping Lead Time: {expedited_avg_lead_time}")
print(f"Lead Time Variability: {expedited_avg_variability}")
# Out:
# **Standard Shipping Performance:**
#         Ship Mode  Total_Shipments   Average_Shipping_Lead_Time  \
# 3  Standard Class             5142 1314 days 08:01:52.941176464
#
#         Lead_Time_Variability
# 3 262 days 09:36:10.041529276
# **Expedited Shipping Performance (Aggregated):**
# Total Shipments: 3407
# Average Shipping Lead Time: 1331 days 20:30:32.526971760
# Lead Time Variability: 260 days 10:04:21.607248252

# %% [markdown]
# ### Evaluation of Cost-Time Tradeoffs
# Based on the analysis of shipping modes, we can observe the following cost-time tradeoffs:

# %% [markdown]
# Standard Class (Standard Shipping)  This mode handles the vast majority of shipments and typically has the lowest *implied* cost, as it also has a relatively shorter average lead time compared to 'First Class' and 'Same Day', but slightly longer than 'Second Class'. Its lead time variability is also in a similar range to other modes.

# %% [markdown]
# Expedited Shipping (First Class, Same Day, Second Class) These modes generally offer faster delivery times (or specific delivery windows like 'Same Day'), but usually come at a higher cost. We see that 'Same Day' and 'First Class' actually have longer average lead times than 'Standard Class' in this dataset, which is counter-intuitive for 'expedited' services.

# %% [markdown]
# Given the current data, 'Standard Class' appears to be the most efficient in terms of lead time for its likely lower cost, although the specific cost data for each shipping mode is not available to confirm direct cost-time tradeoffs. The 'Same Day' option, despite its name, shows a longer average lead time than 'Standard Class', which is a significant point for further investigation if expedited services are a business priority.

# %%
df=pd.read_csv(r"C:\Users\I SKY\Downloads/Nassau Candy Distributor.csv")
df.head()
# Out:
#    Row ID                      Order ID  Order Date   Ship Date  \
# 0       1  US-2021-103800-CHO-MIL-31000  03-01-2024  30-06-2026
# 1       2  US-2021-112326-CHO-TRI-54000  04-01-2024  01-07-2026
# 2       3  US-2021-112326-CHO-NUT-13000  04-01-2024  01-07-2026
# 3       4  US-2021-112326-CHO-SCR-58000  04-01-2024  01-07-2026
# 4       5  US-2021-141817-CHO-TRI-54000  05-01-2024  05-07-2026
#
#         Ship Mode  Customer ID Country/Region          City State/Province  \
# 0  Standard Class       103800  United States       Houston          Texas
# 1  Standard Class       112326  United States    Naperville       Illinois
# 2  Standard Class       112326  United States    Naperville       Illinois
# 3  Standard Class       112326  United States    Naperville       Illinois
# 4  Standard Class       141817  United States  Philadelphia   Pennsylvania
#
#   Postal Code   Division    Region     Product ID  \
# 0       77095  Chocolate  Interior  CHO-MIL-31000
# ...

# %%
import sys
# !{sys.executable} -m pip install plotly
# Out:
# 'c:\Users\I' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import plotly.express as px

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], format='mixed', dayfirst=True)
df['Ship Date'] = pd.to_datetime(df['Ship Date'], format='mixed', dayfirst=True)

import streamlit as st
import pandas as pd
import plotly.express as px

# -------------------------------------------------------------------------
# PRE-REQUISITES & ASSUMPTIONS
# The variable `df` is expected to be loaded before this code runs.
# We assume the following column names exist in your `df`:
# 'Order Date', 'Ship Date', 'State', 'Region', 'Ship Mode', 'Route', 
# 'Lead Time', and 'Order ID'. Modify these string keys if yours differ.
# -------------------------------------------------------------------------

st.set_page_config(page_title="Shipping Efficiency Dashboard", layout="wide")
st.title("📦 Shipping & Route Efficiency Dashboard")

# --- DATA PREPARATION ---
# Ensure dates are datetime objects for the filter
df['Order Date'] = pd.to_datetime(df['Order Date'], format='mixed', dayfirst=True)
df['Ship Date'] = pd.to_datetime(df['Ship Date'], format='mixed', dayfirst=True)

# If Lead Time doesn't exist, calculate it (Ship Date - Order Date)
if 'Lead Time' not in df.columns:
    df['Lead Time'] = (df['Ship Date'] - df['Order Date']).dt.days

# --- GLOBAL FILTERS (SIDEBAR) ---
st.sidebar.header("Global Filters")

# 1. Date Range Filter
min_date = df['Order Date'].min().date()
max_date = df['Order Date'].max().date()
date_selection = st.sidebar.date_input(
    "Select Date Range",
    value=(min_date, max_date),
    min_value=min_date,
    max_value=max_date
)

# Handle cases where the user hasn't selected the end date yet
if len(date_selection) == 2:
    start_date, end_date = date_selection
else:
    start_date = end_date = date_selection[0]

# 2. Region / State Selector
all_states = sorted(df['State'].dropna().unique())
selected_states = st.sidebar.multiselect(
    "Select Region / State(s)",
    options=all_states,
    default=all_states
)

# 3. Ship Mode Filter
all_modes = df['Ship Mode'].dropna().unique()
selected_modes = st.sidebar.multiselect(
    "Select Ship Mode(s)",
    options=all_modes,
    default=all_modes
)

# 4. Lead-time Threshold Slider
min_lead = int(df['Lead Time'].min())
max_lead = int(df['Lead Time'].max())
lead_threshold = st.sidebar.slider(
    "Max Lead-Time Threshold (Days)",
    min_value=min_lead,
    max_value=max_lead,
    value=max_lead
)

# --- APPLY FILTERS TO DATASET ---
mask = (
    (df['Order Date'].dt.date >= start_date) &
    (df['Order Date'].dt.date <= end_date) &
    (df['State'].isin(selected_states)) &
    (df['Ship Mode'].isin(selected_modes)) &
    (df['Lead Time'] <= lead_threshold)
)
filtered_df = df[mask]

# Stop execution if filters result in an empty dataset
if filtered_df.empty:
    st.warning("No data available with the current filter settings. Please adjust your filters.")
    st.stop()

# --- LAYOUT & SECTIONS ---

st.markdown("---")

# ==========================================
# SECTION 1: Route Efficiency Overview
# ==========================================
st.header("1. Route Efficiency Overview")
col1, col2 = st.columns(2)

with col1:
    st.subheader("Average Lead Time by Route")
    # Aggregate data by Route
    route_avg_time = filtered_df.groupby('Route', as_index=False)['Lead Time'].mean().sort_values(by='Lead Time')
    fig_route = px.bar(
        route_avg_time.head(10), # Showing top 10 for readability
        x='Lead Time', y='Route', orientation='h',
        title="Top 10 Fastest Routes (Avg Lead Time)",
        color='Lead Time', color_continuous_scale='Viridis_r'
    )
    st.plotly_chart(fig_route, use_container_width=True)

with col2:
    st.subheader("Route Performance Leaderboard")
    # Provide a detailed table grouped by route
    leaderboard = filtered_df.groupby('Route').agg(
        Total_Orders=('Order ID', 'nunique'),
        Avg_Lead_Time=('Lead Time', 'mean'),
        Max_Lead_Time=('Lead Time', 'max')
    ).reset_index().sort_values(by='Avg_Lead_Time')
    st.dataframe(leaderboard.style.format({"Avg_Lead_Time": "{:.2f}"}), use_container_width=True, height=350)

st.markdown("---")

# ==========================================
# SECTION 2: Geographic Shipping Map
# ==========================================
st.header("2. Geographic Shipping Map")
col3, col4 = st.columns(2)

with col3:
    st.subheader("US Heatmap of Shipping Efficiency")
    # Assumes 'State' contains 2-letter US State codes (e.g., 'CA', 'TX')
    state_perf = filtered_df.groupby('State', as_index=False)['Lead Time'].mean()
    fig_map = px.choropleth(
        state_perf,
        locations='State',
        locationmode="USA-states",
        color='Lead Time',
        scope="usa",
        color_continuous_scale="RdYlGn_r", # Green is good (low time), Red is bad (high time)
        title="Average Lead Time by State"
    )
    st.plotly_chart(fig_map, use_container_width=True)

with col4:
    st.subheader("Regional Bottlenecks")
    # Highlight the top 10 states with the highest average lead time
    bottlenecks = state_perf.sort_values(by='Lead Time', ascending=False).head(10)
    fig_bottleneck = px.bar(
        bottlenecks,
        x='State', y='Lead Time',
        title="Top 10 Slowest States (Bottlenecks)",
        color='Lead Time', color_continuous_scale='Reds'
    )
    st.plotly_chart(fig_bottleneck, use_container_width=True)

st.markdown("---")

# ==========================================
# SECTION 3: Ship Mode Comparison
# ==========================================
st.header("3. Ship Mode Comparison")

st.subheader("Lead Time Distribution by Shipping Method")
# A Box plot is excellent for showing distributions and outliers across categories
fig_ship_mode = px.box(
    filtered_df,
    x='Ship Mode', y='Lead Time',
    color='Ship Mode',
    title="Lead Time Variability per Shipping Mode"
)
st.plotly_chart(fig_ship_mode, use_container_width=True)

st.markdown("---")

# ==========================================
# SECTION 4: Route Drill-Down
# ==========================================
st.header("4. Route Drill-Down")

# Allow user to pick a specific route from the filtered data for deep diving
specific_route = st.selectbox("Select a Route for Drill-Down", options=filtered_df['Route'].unique())
drill_down_df = filtered_df[filtered_df['Route'] == specific_route]

col5, col6 = st.columns([1, 2])

with col5:
    st.subheader("State-Level Insights")
    # Breakdown of performance inside this specific route by State
    state_breakdown = drill_down_df.groupby('State').agg(
        Orders=('Order ID', 'count'),
        Avg_Time=('Lead Time', 'mean')
    ).reset_index()
    st.dataframe(state_breakdown, use_container_width=True)

with col6:
    st.subheader("Order-Level Shipment Timelines")
    # Gantt chart (timeline) for individual orders on this route
    # Taking top 20 to keep the chart clean, but you can adjust this
    timeline_df = drill_down_df.head(20) 
    
    if not timeline_df.empty:
        fig_timeline = px.timeline(
            timeline_df,
            x_start="Order Date",
            x_end="Ship Date",
            y="Order ID",
            color="Ship Mode",
            title=f"Shipment Timeline for top recent orders on route: {specific_route}"
        )
        # Update y-axis to show orders from top to bottom
        fig_timeline.update_yaxes(autorange="reversed") 
        st.plotly_chart(fig_timeline, use_container_width=True)
    else:
        st.info("No timeline data available for this route.")
# Out:
# 2026-05-03 18:55:22.213 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-03 18:55:22.231 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-03 18:55:22.234 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-03 18:55:22.241 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-03 18:55:22.399 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-03 18:55:22.405 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-03 18:55:22.407 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
